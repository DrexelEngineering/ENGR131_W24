# %% [markdown]
# #  🧪🖥 Week 5 - Set up Local Jupyter Notebooks
#
# In this lab, you will install software to run Jupyter Notebooks locally so that you can complete your assignments on your own computer.

# %% [markdown]
# ## A. Install Anaconda
#
# Please choose the appropriate subsection based on whether you use a computer with Windows, Mac, or Linux.

# %% [markdown]
# ### Windows
#
# 0. Open [this link](https://www.anaconda.com/download) to download Anaconda in a browser tab.
#
# 1. Follow the instructions in the documentation below.

# %%
from IPython.display import IFrame

IFrame(src="https://docs.anaconda.com/anaconda/install/windows/", width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://docs.anaconda.com/anaconda/install/windows/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### MacOS
#
#
# 0. Click the Apple in the upper left corner of your screen, and choose "About this Mac" from the drop down menu.
#
# In the window that pops up, look for the word **Processor**.
#
# * If the words following **Processor** include "Intel", follow the instructions under #### Intel below.
#
# * If the words following **Processor** include "M1", "M2", or "M3", follow the instructions under #### M1-3 below.
#
# #### Intel
#
# 1. Go to [Anaconda downloads](https://www.anaconda.com/download#downloads).
#
# Click the link titled *64-Bit Graphical Installer (610.5 MB)* under the Mac logo.
#
#
#
# #### M1-3
#
# 1. Go to [Anaconda downloads](https://www.anaconda.com/download#downloads).
#
# Click the link titled *64-Bit (M1) Graphical Installer (643.9 MB)* under the Mac logo.
#
#
# ### Continue below
#
# 2. Follow the instructions below starting at Step 2.

# %%
IFrame(src="https://docs.anaconda.com/anaconda/install/mac-os/", width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://docs.anaconda.com/anaconda/install/mac-os/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Linux
#
# 0. Open [this link](https://www.anaconda.com/download) to download Anaconda in a browser tab.
#
# 1. Follow the instructions in the documentation below.

# %%
IFrame(src="https://docs.anaconda.com/anaconda/install/linux/", width=1200, height=600)
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="https://docs.anaconda.com/anaconda/install/linux/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## B. Install JupyterLab
#
# 0. Open the Anaconda Navigator application you just installed.
#
# 1. Click "Install" under JupyterLab.
#
#    1a. If "Launch" appears under JupyterLab instead of "Install", then you do not need to take this step.

# %%
from IPython.display import Image

# Specify the filename of the image in the same folder
image_filename = 'installJupyterLab.jpg'

# Display the image
Image(filename=image_filename)

# %% [markdown]
# ## C. Create an Environment for ENGR 131
#
# 0. Download [this file](../../files/engr131_24.yml) to a location where you can find it. Do not change the file name, which should be  `engr131_24.yml`.
#
# 1. In Anaconda Navigator, click Environments on the left navigation panel.
#
# 2. Click Import at the bottom of the window.
#
# 3. Choose the file that you downloaded in Step 0. Leave the new environment name as `engr131_24`.
#
# 4. Click Import.
#
# 5. Make sure that engr131_24 is now in the list under "base(root)" and is highlighted in green. Click the name "engr131_24" to select it if it is not green.

# %%
from IPython.display import Image

# Specify the filename of the image in the same folder
image_filename = 'envImport.jpg'

# Display the image
Image(filename=image_filename)

# %% [markdown]
# ## D. Launch JupyterLab
#
# 0. In Anaconda Navigator, click the Home button in the left navigation panel.
#
# 1. Find JupyterLab (not Jupyter notebooks) in the applications panel.
#
# 2. Click "Launch" under JupyterLab.

# %%
# Specify the filename of the image in the same folder
image_filename = 'launchJupyterLab.jpg'

# Display the image
Image(filename=image_filename)

# %% [markdown]
# ## E. Create the engr131 Kernel
#
# ### Windows
#
# 0. Go to Anaconda Navigator Home
#
# 1. Look for the CMD.exe PROMPT application, and click Install beneath it.
#
# 2. Launch CMD.exe PROMPT application by clicking Launch beneath it.
#
# 3. In the command prompt window that opens, enter exactly the following at the prompts.
#
# `conda activate engr131_24`
#
# `conda install ipykernel`
#
# `ipython kernel install --user --name=engr131`
#
# `conda deactivate`
#
# 3. Then, close the command prompt window. Proceed to Step F. Test JupyterLab with engr131 Kernel.
#
#
# ### Mac or Linux
#
# 0. In your default browser, JupyterLab should be open.
#
# 1. Click on "Terminal" to open a terminal.
#
# 2. In the terminal window, enter the following at the prompts.
#
# `conda activate engr131_24`
#
# `conda install ipykernel`
#
# `ipython kernel install --user --name=engr131`
#
# `conda deactivate`
#
# 3. Then, close the terminal window by click the "x" beside "Terminal 1".
#
#
# ## F. Test JupyterLab with engr131 Kernel
#
# 0. In your default browser, JupyterLab should be open.
#
# 1. Click the button indicated below to upload the midterm .ipynb file (or a quiz .ipynb file that you have saved on your computer).

# %%
from IPython.display import Image

# Specify the filename of the image in the same folder
image_filename = 'uploadNotebook.jpg'

# Display the image
Image(filename=image_filename)

# %% [markdown]
# 2. Click on the uploaded file name in the left panel to open it.
#
# 3. Click on the words "Python 3 (ipykernel)" in the upper right part of the window.
#
# 4. In the dialog box that opens, use the dropdown menu to choose the engr131 kernel.
#
# 5. Click the button indicated below to always start the preferred kernel. Then, click Select.

# %%
from IPython.display import Image

# Specify the filename of the image in the same folder
image_filename = 'selectKernelv1.jpg'

# Display the image
Image(filename=image_filename)

# %% [markdown]
# 7. Try to execute the cells in the notebook.
#
# 8. Work with a TA or LA if you receive an error.
#
# 9. When running this file produces an output.log file in the panel on the left of the window, you have confirmed that you have a local JupyterLab working that you can use on future assignments.
